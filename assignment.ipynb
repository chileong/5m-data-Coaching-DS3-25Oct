# %%
import numpy as np
import pandas as pd
df = pd.read_csv('vgsales.csv')
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# Which 5 games have the highest global sales? What do they have in common?

# %%
df.sort_values(by='Global_Sales',ascending=[False]).head(5)
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# Calculate total sales by genre. Which genre generates the most revenue globally?

# %%
df.groupby('Genre')['Global_Sales'].sum().sort_values(ascending=[False])
# Out:
# Genre
# Action          1751.18
# Sports          1330.93
# Shooter         1037.37
# Role-Playing     927.37
# Platform         831.37
# Misc             809.96
# Racing           732.04
# Fighting         448.91
# Simulation       392.20
# Puzzle           244.95
# Adventure        239.04
# Strategy         175.12
# Name: Global_Sales, dtype: float64

# %% [markdown]
# Find the average sales per game for each platform. Which platforms have the highest average?

# %%
df[df['Platform']=='GEN']

# %%
df.groupby('Platform').agg(Global_Sales_sum=('Global_Sales','sum'),Global_Sales_mean=('Global_Sales','mean')).sort_values(by='Global_Sales_mean',ascending=[False])
# Out:
#           Global_Sales_sum  Global_Sales_mean
# Platform
# GB                  255.45           2.606633
# NES                 251.07           2.561939
# GEN                  28.36           1.050370
# SNES                200.05           0.837029
# PS4                 278.10           0.827679
# X360                979.96           0.774672
# 2600                 97.08           0.729925
# PS3                 957.84           0.720722
# Wii                 926.71           0.699404
# N64                 218.88           0.686144
# XOne                141.06           0.662254
# PS                  730.66           0.610920
# PS2                1255.64           0.581046
# WiiU                 81.86           0.572448
# 3DS                 247.46           0.486169
# GBA                 318.50           0.387470
# DS                  822.49           0.380254
# GC                  199.36           0.358561
# XB                  258.26           0.313422
# ...

# %% [markdown]
# Which publisher has released the most games? Do they also have the highest total sales?

# %%
df.groupby('Publisher').agg(Name_count=('Name','nunique'),Sales=('Global_Sales','sum')).sort_values(by='Name_count',ascending=[False])
# Out:
#                               Name_count    Sales
# Publisher
# Namco Bandai Games                   776   254.09
# Nintendo                             667  1786.56
# Konami Digital Entertainment         640   283.64
# Sony Computer Entertainment          622   607.50
# Electronic Arts                      606  1110.32
# ...                                  ...      ...
# New World Computing                    1     0.01
# Nexon                                  1     0.03
# Nichibutsu                             1     0.28
# Nippon Amuse                           1     0.09
# Giza10                                 1     0.02
#
# [578 rows x 2 columns]

# %%
df.groupby('Publisher').agg(Name_count=('Name','nunique'),Sales=('Global_Sales','sum')).sort_values(by='Sales',ascending=[False])
# Out:
#                              Name_count    Sales
# Publisher
# Nintendo                            667  1786.56
# Electronic Arts                     606  1110.32
# Activision                          417   727.46
# Sony Computer Entertainment         622   607.50
# Ubisoft                             572   474.72
# ...                                 ...      ...
# Interworks Unlimited, Inc.            1     0.01
# Inti Creates                          1     0.01
# Stainless Games                       1     0.01
# Interchannel-Holon                    1     0.01
# New World Computing                   1     0.01
#
# [578 rows x 2 columns]

# %% [markdown]
# For games released after 2010, which genre dominated each region (NA, EU, JP)?

# %%
df1=df[df['Year']>2010]
df1.groupby('Genre').agg(NA_Sales_sum=('NA_Sales','sum'),
                         EU_Sales_sum=('EU_Sales','sum'),
                         JP_Sales_sum=('JP_Sales','sum'),
                         Other_Sales_sum=('Other_Sales','sum'),
                         Global_Sales_sum=('Global_Sales','sum')
                         ).sort_values(by='Global_Sales_sum',ascending=[False])
# Out:
#               NA_Sales_sum  EU_Sales_sum  JP_Sales_sum  Other_Sales_sum  \
# Genre
# Action              227.46        200.52         62.15            65.56
# Shooter             184.53        142.54         11.42            46.71
# Role-Playing         79.02         60.06         76.77            19.24
# Sports              105.88         86.60         10.92            28.86
# Misc                 70.29         40.88         17.25            12.78
# Platform             38.31         30.14         12.07             8.25
# Racing               31.36         41.00          5.61            10.75
# Fighting             31.49         16.65         12.24             6.81
# Simulation           15.46         18.43         11.54             3.78
# Adventure            14.34         13.85         11.84             4.39
# Strategy              7.53          7.89          4.58             1.99
# Puzzle                2.84          3.58          2.91             0.71
#
# ...

# %% [markdown]
# Calculate the percentage of global sales that each region contributes. Which region is most important?

# %%
NA_Sales_sum = df['NA_Sales'].sum()
EU_Sales_sum = df['EU_Sales'].sum()
JP_Sales_sum = df['JP_Sales'].sum()
Other_Sales_sum = df['Other_Sales'].sum()
Global_Sales_sum = df['Global_Sales'].sum() 
print(f"NA_Sales_sum: {(NA_Sales_sum/Global_Sales_sum):.2f},EU_Sales_sum: {(EU_Sales_sum/Global_Sales_sum):.2f},JP_Sales_sum: {(JP_Sales_sum/Global_Sales_sum):.2f},Other_Sales_sum: {(Other_Sales_sum/Global_Sales_sum):.2f}")
# Out:
# NA_Sales_sum: 0.49,EU_Sales_sum: 0.27,JP_Sales_sum: 0.14,Other_Sales_sum: 0.09

# %% [markdown]
# Find games where Japanese sales exceed North American sales. What patterns do you notice about genre or
# publisher?

# %%
df1=df[df['JP_Sales']>df['NA_Sales']]
df1.groupby('Genre').agg(JP_Sales_sum=('JP_Sales','sum'),
                         Count=('Name','nunique')
                         ).sort_values(by='JP_Sales_sum',ascending=[False])
# Out:
#               JP_Sales_sum  Count
# Genre
# Role-Playing        260.11    690
# Sports              108.08    360
# Action               96.81    605
# Misc                 80.81    433
# Fighting             58.72    273
# Simulation           51.99    194
# Strategy             44.06    216
# Adventure            41.27    616
# Platform             40.45     93
# Puzzle               38.97     90
# Racing               19.52     75
# Shooter              16.93    103

# %%
df1.groupby('Publisher').agg(JP_Sales_sum=('JP_Sales','sum'),
                             Count=('Name','nunique')
                             ).sort_values(by='JP_Sales_sum',ascending=[False])
# Out:
#                               JP_Sales_sum  Count
# Publisher
# Nintendo                            178.19    276
# Namco Bandai Games                  116.01    580
# Konami Digital Entertainment         79.82    334
# Sega                                 48.98    254
# Capcom                               48.09    126
# ...                                    ...    ...
# Kalypso Media                         0.01      1
# Commseed                              0.01      1
# Michaelsoft                           0.01      1
# Moss                                  0.01      1
# Naxat Soft                            0.01      1
#
# [270 rows x 2 columns]
